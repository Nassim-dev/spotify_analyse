# %%
import requests
import base64
from urllib.parse import urlencode
from http.server import HTTPServer, BaseHTTPRequestHandler

# %%
access_token = None

class SpotifyAuthClient:
    def __init__(self, client_id, client_secret, redirect_uri):
        self.client_id = client_id
        self.client_secret = client_secret
        self.redirect_uri = redirect_uri
        self.auth_base_url = "https://accounts.spotify.com"
        self.api_base_url = "https://api.spotify.com/v1"
    
    def get_auth_url(self, scope=None):
        params = {
            'client_id': self.client_id,
            'response_type': 'code',
            'redirect_uri': self.redirect_uri,
            'scope': scope or '',
        }
        return f"{self.auth_base_url}/authorize?{urlencode(params)}"
    
    def get_token(self, code):
        auth_header = base64.b64encode(f"{self.client_id}:{self.client_secret}".encode()).decode()
        response = requests.post(
            f"{self.auth_base_url}/api/token",
            headers={
                'Authorization': f'Basic {auth_header}',
                'Content-Type': 'application/x-www-form-urlencoded',
            },
            data={
                'grant_type': 'authorization_code',
                'code': code,
                'redirect_uri': self.redirect_uri,
            }
        )
        if response.status_code == 200:
            return response.json()
        else: Exception(f"Erreur lors de la récupération du token: {response.text}")

# %%
def run_server(client, scope):
    auth_url = client.get_auth_url(scope)
    print(f"Ouvrez cette URL dans votre navigateur : {auth_url}")

    class RequestHandler(BaseHTTPRequestHandler):
        def do_GET(self):
            global access_token
            if "/callback" in self.path:
                query = self.path.split('?')[-1]
                params = dict(param.split('=') for param in query.split('&'))
                code = params.get('code')
                self.send_response(200)
                self.end_headers()
                self.wfile.write(b"Authentification reussie! Vous pouvez fermer cette fenetre")
                
                # get token
                token_info = client.get_token(code)
                access_token = token_info['access_token']
                print(access_token)
                return

    server = HTTPServer(('localhost', 8000), RequestHandler)
    print("Serveur en attente du callback...")
    server.handle_request()

# %%
if __name__ == "__main__":
    client_id = '6094c6c177374701a0abdb52fbb627ad'
    client_secret = '0723befe0b9249b9a7036423e27a0633'
    redirect_uri = 'http://localhost:8000/callback'
    scope = 'user-read-private user-read-email user-top-read'

    auth_client = SpotifyAuthClient(client_id, client_secret, redirect_uri)
    
    run_server(auth_client, scope)
# Out:
# Ouvrez cette URL dans votre navigateur : https://accounts.spotify.com/authorize?client_id=6094c6c177374701a0abdb52fbb627ad&response_type=code&redirect_uri=http%3A%2F%2Flocalhost%3A8000%2Fcallback&scope=user-read-private+user-read-email+user-top-read
# Serveur en attente du callback...
# 127.0.0.1 - - [20/Dec/2024 14:25:30] "GET /callback?code=AQAz4q3cu1V3R8J4ozmVsEAG1EZaRFxGD37w3qRhUNbhPu6VGJenNMrPhky1-zazD9x__4qz4x7fA4Aq1tPBHbY3IObH1DUSGSti4zqVwyowKfXOjWT7jJyMH8S-YlaxIgWLNJH9jUsZMLzJP-QAPeH30_2hkD0srlRtyRqCp7EAR8tv_kXW2klJaPQBM60Yhs-ecs6xaiu-z7uhya_HOBV4XHGvu7dA3kIHAF56NPqpyTSiqQ HTTP/1.1" 200 -
# BQCuyPH1gRYzWV1SER-P6smM_ZNkUZeK_4hbcwcH6Y-dLHnkjhKZijsbuI5snQxcPyCGzM4PBrLS1x4o47yxbCr1THXZDSS-P_3n0MzntDxbIM8g2lrBiG7JsIK8mVegwMGs9Gwf4_th-96AuYQaluE5UO63b5Dcr_91NeO4jc6FHKwCOho-uzzfLzD4efroUKWGVsksXUsHR_kVxlVoO_f--2wqHvDTZFh9-8s

# %%
top_tracks = []

# %%
def get_top_tracks(limit=50, time_range="long_term"):
    global top_tracks
    if not access_token:
        print("Erreur : Aucun token d'accès disponible. Authentifiez-vous d'abord")
        return
    
    url = "https://api.spotify.com/v1/me/top/tracks"
    headers = {"Authorization": f"Bearer {access_token}"}
    params = {"time_range": time_range, "limit": limit}
    
    response = requests.get(url, headers=headers, params=params)
    if response.status_code == 200:
        top_tracks = response.json()["items"] 
        print("Votre top tracks :")
        for idx, track in enumerate(top_tracks, start=1):
            print(f"{idx}. {track['name']} - {', '.join(artist['name'] for artist in track['artists'])}")
    else:
        print("Erreur :", response.status_code, response.json())

# %%
get_top_tracks()
# Out:
# Votre top tracks :
# 1. violet - Lexie Carroll
# 2. the sky looked nice today - Lexie Carroll
# 3. Right Now - SR-71
# 4. vampire - Olivia Rodrigo
# 5. With Me - Sum 41
# 6. stranger - Olivia Rodrigo
# 7. Wayfaring Stranger - Ashley Johnson, Troy Baker
# 8. What's Up Danger (with Black Caviar) - Blackway, Black Caviar
# 9. My Girl - The Temptations
# 10. The Rock Show - blink-182
# 11. Back To Me - The Rose
# 12. Overcompensate - Twenty One Pilots
# 13. Reckless - Madison Beer
# 14. The Emptiness Machine - Linkin Park
# 15. The Drum - Alan Walker
# 16. Pieces - Sum 41
# 17. In Too Deep - Sum 41
# 18. Shut Up - Alan Walker, UPSAHL
# 19. Landmines - Sum 41
# 20. The Craving (Jenna's version) - Twenty One Pilots
# 21. Fat Lip - Sum 41
# 22. Powered Up - Cobra Man
# 23. Still Waiting - Sum 41
# 24. Pure 90 (Rapping Queen) - Shaka Ponk, Cypress Hill
# 25. Here We Go Again - SR-71
# 26. Halibo - Billx, Dr. Peacock
# 27. SATIVA - Yvnnis
# 28. Elle pleut - Nekfeu, Nemir
# 29. My wing - Rave music edit - Billx, Otyken
# 30. GARE DU NORD - Yvnnis
# 31. War - Sum 41
# 32. ルージュの伝言 - Yumi Arai
# 33. Let Me Down Slowly - Alec Benjamin
# 34. Lovesick - Alan Walker, Sophie Simmons
# 35. Chemical Burns - Sadistik, Lotte Kestner, Eyedea
# 36. Overcompensate - Twenty One Pilots
# 37. Heavy Is the Crown - Linkin Park
# 38. HÉROS - Yvnnis
# 39. All Falls Down (feat. Juliander) - Alan Walker, Noah Cyrus, Digital Farm Animals, Juliander
# 40. Altay - Ummet Ozcan, Otyken
# 41. number one girl - ROSÉ
# 42. Hello World - Alan Walker, Torine
# 43. Taste Me - Angy
# 44. Sing Me to Sleep - Alan Walker
# 45. Waiting On A Twist Of Fate - Sum 41
# 46. Anthropology - Vladimir Cauchemar
# 47. Alone, Pt. II - Alan Walker, Ava Max
# 48. Sorry - Alan Walker, ISÁK
# 49. Stained - Linkin Park
# 50. Take on Me - Ashley Johnson, Chris Rondinella

# %%
import pandas as pd

tracks_data = []
for track in top_tracks:
    track_info = {
        'name': track['name'],
        'artists': ', '.join(artist['name'] for artist in track['artists']),
        'album': track['album']['name'],
        'popularity': track['popularity'],
        'id_track' : track['id']
    }
    tracks_data.append(track_info)

df_tracks = pd.DataFrame(tracks_data)

display(df_tracks)
# Out:
#                                     name  \
# 0                                 violet
# 1              the sky looked nice today
# 2                              Right Now
# 3                                vampire
# 4                                With Me
# 5                               stranger
# 6                     Wayfaring Stranger
# 7   What's Up Danger (with Black Caviar)
# 8                                My Girl
# 9                          The Rock Show
# 10                            Back To Me
# 11                        Overcompensate
# 12                              Reckless
# 13                 The Emptiness Machine
# 14                              The Drum
# 15                                Pieces
# 16                           In Too Deep
# 17                               Shut Up
# 18                             Landmines
# 19         The Craving (Jenna's version)
# 20                               Fat Lip
# 21                            Powered Up
# 22                         Still Waiting
# 23               Pure 90 (Rapping Queen)
# 24                      Here We Go Again
# 25                                Halibo
# 26                                SATIVA
# 27                            Elle pleut
# 28             My wing - Rave music edit
# 29                          GARE DU NORD
# 30                                   War
# 31                               ルージュの伝言
# 32                    Let Me Down Slowly
# 33                              Lovesick
# 34                        Chemical Burns
# 35                        Overcompensate
# 36                    Heavy Is the Crown
# 37                                 HÉROS
# 38      All Falls Down (feat. Juliander)
# 39                                 Altay
# 40                       number one girl
# 41                           Hello World
# 42                              Taste Me
# 43                      Sing Me to Sleep
# 44            Waiting On A Twist Of Fate
# 45                          Anthropology
# 46                         Alone, Pt. II
# 47                                 Sorry
# 48                               Stained
# 49                            Take on Me
#
#                                               artists  \
# 0                                       Lexie Carroll
# 1                                       Lexie Carroll
# 2                                               SR-71
# 3                                      Olivia Rodrigo
# 4                                              Sum 41
# 5                                      Olivia Rodrigo
# 6                          Ashley Johnson, Troy Baker
# 7                              Blackway, Black Caviar
# 8                                     The Temptations
# 9                                           blink-182
# 10                                           The Rose
# 11                                  Twenty One Pilots
# 12                                       Madison Beer
# 13                                        Linkin Park
# 14                                        Alan Walker
# 15                                             Sum 41
# 16                                             Sum 41
# 17                                Alan Walker, UPSAHL
# 18                                             Sum 41
# 19                                  Twenty One Pilots
# 20                                             Sum 41
# 21                                          Cobra Man
# 22                                             Sum 41
# 23                           Shaka Ponk, Cypress Hill
# 24                                              SR-71
# 25                                 Billx, Dr. Peacock
# 26                                             Yvnnis
# 27                                      Nekfeu, Nemir
# 28                                      Billx, Otyken
# 29                                             Yvnnis
# 30                                             Sum 41
# 31                                          Yumi Arai
# 32                                      Alec Benjamin
# 33                        Alan Walker, Sophie Simmons
# 34                    Sadistik, Lotte Kestner, Eyedea
# 35                                  Twenty One Pilots
# 36                                        Linkin Park
# 37                                             Yvnnis
# 38  Alan Walker, Noah Cyrus, Digital Farm Animals,...
# 39                                Ummet Ozcan, Otyken
# 40                                               ROSÉ
# 41                                Alan Walker, Torine
# 42                                               Angy
# 43                                        Alan Walker
# 44                                             Sum 41
# 45                                 Vladimir Cauchemar
# 46                               Alan Walker, Ava Max
# 47                                  Alan Walker, ISÁK
# 48                                        Linkin Park
# 49                   Ashley Johnson, Chris Rondinella
#
#                                                 album  popularity  \
# 0                                              violet          28
# 1                                when the sun came up          28
# 2                                  Now You See Inside          56
# 3                                                GUTS          82
# 4                                     Underclass Hero          60
# 5                                      GUTS (spilled)          70
# 6         The Last of Us Part II: Covers and Rarities          44
# 7   Spider-Man: Into the Spider-Verse (Soundtrack ...          68
# 8                         The Temptations Sing Smokey          78
# 9                      Take Off Your Pants And Jacket          68
# 10                                               DUAL          62
# 11                                     Overcompensate          62
# 12                                           Reckless          70
# 13                              The Emptiness Machine          85
# 14                                           The Drum          59
# 15                                              Chuck          67
# 16                              All Killer, No Filler          74
# 17                             Walkerverse Pt. I & II          53
# 18                                    Heaven :x: Hell          62
# 19                                             Clancy          61
# 20                              All Killer, No Filler          72
# 21                                         Powered Up          38
# 22                           Does This Look Infected?          71
# 23                                          Apelogies          45
# 24                      Here We Go Again (US Edition)          39
# 25                                             Halibo          46
# 26                              L'AFRO OU LES TRESSES          38
# 27                 Les étoiles vagabondes : expansion          62
# 28                          My wing (Rave music edit)          44
# 29                                       GARE DU NORD          38
# 30                                          13 Voices          67
# 31                                        COBALT HOUR          57
# 32                                   Narrated For You          83
# 33                             Walkerverse Pt. I & II          48
# 34                                        Ultraviolet          28
# 35                                             Clancy          67
# 36                                 Heavy Is the Crown          82
# 37                                              NOVAE          40
# 38                                    Different World          63
# 39                                              Altay          47
# 40                                              rosie          80
# 41                                        Hello World          50
# 42                                           Taste Me          34
# 43                                    Different World          59
# 44                                    Heaven :x: Hell          50
# 45                                       Anthropology          46
# 46                                    World Of Walker          71
# 47                                    World Of Walker          52
# 48                                          From Zero          78
# 49        The Last of Us Part II: Covers and Rarities          51
#
#                   id_track
# 0   6wOypcYXXeROfeVQLZ0sVU
# 1   3XlMpNZyNcqH7GxJw0NWH9
# 2   3iwsyTZzOWHZbHffBEyi1N
# 3   1kuGVB7EU95pJObxwvfwKS
# 4   1OTvWduKQV0MQd2gnGM9He
# 5   2U3jOPfO4wZZFaaWS4Dcj6
# 6   3wR4Cnadsl0xnpEAYkr3my
# 7   5zsHmE2gO3RefVsPyw2e3T
# 8   745H5CctFr12Mo7cqa1BMH
# 9   2ydUT1pFhuLDnouelIv4WH
# 10  20Ahyv93KKjMuDHAVy2yjr
# 11  0wEGo9LsSrSUz9HOtraWAO
# 12  5ajjAnNRh8bxFvaVHzpPjh
# 13  2PnlsTsOTLE5jnBnNe2K0A
# 14  1zOOl8f7qkjj0AmvlCfLyQ
# 15  1ibeKVCiXORhvUpMmtsQWq
# 16  1HNE2PX70ztbEl6MLxrpNL
# 17  1hf9Wu2l0XIgAcTZLSAUJe
# 18  5Zq5HHYL8YX2U1S5hY5tRZ
# 19  4hfqe20vqkuRv1RDsA1LbQ
# 20  4KacUpvbA3Mfo05gttTjhN
# 21  35YuZV3Fyffqu9fOO2wXtm
# 22  0jqK7sGTLsHPkQrrcrGuKD
# 23  24ZEVCdOTKgdcM41B598NM
# 24  3JMy4HCSvdwY6FMtvkdKfF
# 25  6M8EMAnTPPnZN58u94iPzg
# 26  2qqXlBPzplDTtKUvbwQ3AI
# 27  4kqsT3yDyJr1KZ2AkM9qfD
# 28  6RBTZTDDdF6LtHRcn4Stlr
# 29  03Wv9gvnH45UU6ssSFai0x
# 30  23Vf9hNoBN8AacpUUHbiRy
# 31  1jw992uwXhqJJ0H42ucTRL
# 32  2qxmye6gAegTMjLKEBoR3d
# 33  2ECNBJ0b112QmhoBHKq8O6
# 34  673iPvgqnCCZdsYhA9qzE6
# 35  1LAlLBTGBUO0MDA8IbSysd
# 36  3fgehc497TFqKH1zBL2YNK
# 37  6rXrpyjMECjAuLlgcW5TXz
# 38  1HvCFAUIWQsWV9zud3UhDl
# 39  2os0CdL7lnGDEpEFMGLcgG
# 40  1lcBt7LoEikqYmhUoa2cez
# 41  1zS7wXUlPhxdOgGZ7RorQ2
# 42  1lPfpbethBQKiALEZ6hjsf
# 43  1tfVpMI8G6EakZU4rEja4w
# 44  4UuGBLZH6ANkF51PqLeXfP
# 45  2v7HFbmmCeraARmBma5pwG
# 46  28VbwtsYnj85UEODGpQRem
# 47  6k1Q8mNcA2jFH0uv5B6g9G
# 48  0J1IJsMbKWb5g2sJArTkGF
# 49  5s78Y4ulsGO9BJh5s3GrL9

# %%
tracks = pd.read_csv("./tracks_features.csv")
tracks.rename(columns={"id":"id_track"}, inplace=True)
tracks.head(5)
# Out:
#                  id_track                   name                      album  \
# 0  7lmeHLHBe4nmXzuXc0HDjk                Testify  The Battle Of Los Angeles
# 1  1wsRitfRRtWyEapl0q22o8        Guerrilla Radio  The Battle Of Los Angeles
# 2  1hR0fIFK2qRG3f3RF70pb7       Calm Like a Bomb  The Battle Of Los Angeles
# 3  2lbASgTSoDO7MTuLAXlTW0              Mic Check  The Battle Of Los Angeles
# 4  1MQTmpYOZ6fcMQc56Hdo7T  Sleep Now In the Fire  The Battle Of Los Angeles
#
#                  album_id                       artists  \
# 0  2eia0myWFgoHuttJytCxgX  ['Rage Against The Machine']
# 1  2eia0myWFgoHuttJytCxgX  ['Rage Against The Machine']
# 2  2eia0myWFgoHuttJytCxgX  ['Rage Against The Machine']
# 3  2eia0myWFgoHuttJytCxgX  ['Rage Against The Machine']
# 4  2eia0myWFgoHuttJytCxgX  ['Rage Against The Machine']
#
#                    artist_ids  track_number  disc_number  explicit  \
# 0  ['2d0hyoQ5ynDBnkvAbJKORj']             1            1     False
# 1  ['2d0hyoQ5ynDBnkvAbJKORj']             2            1      True
# 2  ['2d0hyoQ5ynDBnkvAbJKORj']             3            1     False
# 3  ['2d0hyoQ5ynDBnkvAbJKORj']             4            1      True
# 4  ['2d0hyoQ5ynDBnkvAbJKORj']             5            1     False
#
#    danceability  ...  speechiness  acousticness  instrumentalness  liveness  \
# 0         0.470  ...       0.0727       0.02610          0.000011    0.3560
# 1         0.599  ...       0.1880       0.01290          0.000071    0.1550
# 2         0.315  ...       0.4830       0.02340          0.000002    0.1220
# 3         0.440  ...       0.2370       0.16300          0.000004    0.1210
# 4         0.426  ...       0.0701       0.00162          0.105000    0.0789
#
#    valence    tempo  duration_ms  time_signature  year  release_date
# 0    0.503  117.906       210133             4.0  1999    1999-11-02
# 1    0.489  103.680       206200             4.0  1999    1999-11-02
# 2    0.370  149.749       298893             4.0  1999    1999-11-02
# 3    0.574   96.752       213640             4.0  1999    1999-11-02
# 4    0.539  127.059       205600             4.0  1999    1999-11-02
#
# [5 rows x 24 columns]

# %%
tracks = pd.read_csv("./tracks_features.csv")
tracks.rename(columns={"id":"id_track"}, inplace=True)
tracks.head(5)
# Out:
#                  id_track                   name                      album  \
# 0  7lmeHLHBe4nmXzuXc0HDjk                Testify  The Battle Of Los Angeles
# 1  1wsRitfRRtWyEapl0q22o8        Guerrilla Radio  The Battle Of Los Angeles
# 2  1hR0fIFK2qRG3f3RF70pb7       Calm Like a Bomb  The Battle Of Los Angeles
# 3  2lbASgTSoDO7MTuLAXlTW0              Mic Check  The Battle Of Los Angeles
# 4  1MQTmpYOZ6fcMQc56Hdo7T  Sleep Now In the Fire  The Battle Of Los Angeles
#
#                  album_id                       artists  \
# 0  2eia0myWFgoHuttJytCxgX  ['Rage Against The Machine']
# 1  2eia0myWFgoHuttJytCxgX  ['Rage Against The Machine']
# 2  2eia0myWFgoHuttJytCxgX  ['Rage Against The Machine']
# 3  2eia0myWFgoHuttJytCxgX  ['Rage Against The Machine']
# 4  2eia0myWFgoHuttJytCxgX  ['Rage Against The Machine']
#
#                    artist_ids  track_number  disc_number  explicit  \
# 0  ['2d0hyoQ5ynDBnkvAbJKORj']             1            1     False
# 1  ['2d0hyoQ5ynDBnkvAbJKORj']             2            1      True
# 2  ['2d0hyoQ5ynDBnkvAbJKORj']             3            1     False
# 3  ['2d0hyoQ5ynDBnkvAbJKORj']             4            1      True
# 4  ['2d0hyoQ5ynDBnkvAbJKORj']             5            1     False
#
#    danceability  ...  speechiness  acousticness  instrumentalness  liveness  \
# 0         0.470  ...       0.0727       0.02610          0.000011    0.3560
# 1         0.599  ...       0.1880       0.01290          0.000071    0.1550
# 2         0.315  ...       0.4830       0.02340          0.000002    0.1220
# 3         0.440  ...       0.2370       0.16300          0.000004    0.1210
# 4         0.426  ...       0.0701       0.00162          0.105000    0.0789
#
#    valence    tempo  duration_ms  time_signature  year  release_date
# 0    0.503  117.906       210133             4.0  1999    1999-11-02
# 1    0.489  103.680       206200             4.0  1999    1999-11-02
# 2    0.370  149.749       298893             4.0  1999    1999-11-02
# 3    0.574   96.752       213640             4.0  1999    1999-11-02
# 4    0.539  127.059       205600             4.0  1999    1999-11-02
#
# [5 rows x 24 columns]

# %%
df_tracks_all = pd.merge(df_tracks, tracks, on='id_track', how='inner')
df_tracks_all.head()
# Out:
#                name_x                        artists_x             album_x  \
# 0           Right Now                            SR-71  Now You See Inside
# 1  Let Me Down Slowly                    Alec Benjamin    Narrated For You
# 2      Chemical Burns  Sadistik, Lotte Kestner, Eyedea         Ultraviolet
#
#    popularity                id_track              name_y             album_y  \
# 0          56  3iwsyTZzOWHZbHffBEyi1N           Right Now  Now You See Inside
# 1          83  2qxmye6gAegTMjLKEBoR3d  Let Me Down Slowly    Narrated For You
# 2          28  673iPvgqnCCZdsYhA9qzE6      Chemical Burns         Ultraviolet
#
#                  album_id                                artists_y  \
# 0  1eDNzJLCxus27R8ZC2hS3z                                ['SR-71']
# 1  6jKZplJpy21R5lHaYHHjmZ                        ['Alec Benjamin']
# 2  4KATPCuUBbfw2ExUd2NSIA  ['Sadistik', 'Eyedea', 'Lotte Kestner']
#
#                                           artist_ids  ...  speechiness  \
# 0                         ['7fTcs8dn9y6XuB2IqZMzBq']  ...       0.0392
# 1                         ['5IH6FPUwQTxPSXurCrcIov']  ...       0.0318
# 2  ['3qgsChODA5iJM6AdA0rr21', '1AgWsZON0joqldki9f...  ...       0.1290
#
#    acousticness  instrumentalness  liveness  valence    tempo  duration_ms  \
# 0      0.000289          0.000007    0.3240    0.731  116.273       167200
# 1      0.740000          0.000000    0.1240    0.483  150.073       169354
# 2      0.107000          0.000000    0.0513    0.254   98.109       237973
#
#    time_signature  year  release_date
# 0             4.0  2000    2000-06-20
# 1             4.0  2018    2018-11-16
# 2             3.0  2014    2014-07-01
#
# [3 rows x 28 columns]

# %%
tracks_data = []
for track in top_tracks:
    track_info = {
        'name': track['name'],
        'artists': ', '.join(artist['name'] for artist in track['artists']),
        'album': track['album']['name'],
        'popularity': track['popularity'],
        'id_track' : track['id']
    }
    tracks_data.append(track_info)

df_tracks = pd.DataFrame(tracks_data)

display(df_tracks)
# Out:
#                                     name  \
# 0                                 violet
# 1              the sky looked nice today
# 2                              Right Now
# 3                                vampire
# 4                                With Me
# 5                               stranger
# 6                     Wayfaring Stranger
# 7   What's Up Danger (with Black Caviar)
# 8                                My Girl
# 9                          The Rock Show
# 10                            Back To Me
# 11                        Overcompensate
# 12                              Reckless
# 13                 The Emptiness Machine
# 14                              The Drum
# 15                                Pieces
# 16                           In Too Deep
# 17                               Shut Up
# 18                             Landmines
# 19         The Craving (Jenna's version)
# 20                               Fat Lip
# 21                            Powered Up
# 22                         Still Waiting
# 23               Pure 90 (Rapping Queen)
# 24                      Here We Go Again
# 25                                Halibo
# 26                                SATIVA
# 27                            Elle pleut
# 28             My wing - Rave music edit
# 29                          GARE DU NORD
# 30                                   War
# 31                               ルージュの伝言
# 32                    Let Me Down Slowly
# 33                              Lovesick
# 34                        Chemical Burns
# 35                        Overcompensate
# 36                    Heavy Is the Crown
# 37                                 HÉROS
# 38      All Falls Down (feat. Juliander)
# 39                                 Altay
# 40                       number one girl
# 41                           Hello World
# 42                              Taste Me
# 43                      Sing Me to Sleep
# 44            Waiting On A Twist Of Fate
# 45                          Anthropology
# 46                         Alone, Pt. II
# 47                                 Sorry
# 48                               Stained
# 49                            Take on Me
#
#                                               artists  \
# 0                                       Lexie Carroll
# 1                                       Lexie Carroll
# 2                                               SR-71
# 3                                      Olivia Rodrigo
# 4                                              Sum 41
# 5                                      Olivia Rodrigo
# 6                          Ashley Johnson, Troy Baker
# 7                              Blackway, Black Caviar
# 8                                     The Temptations
# 9                                           blink-182
# 10                                           The Rose
# 11                                  Twenty One Pilots
# 12                                       Madison Beer
# 13                                        Linkin Park
# 14                                        Alan Walker
# 15                                             Sum 41
# 16                                             Sum 41
# 17                                Alan Walker, UPSAHL
# 18                                             Sum 41
# 19                                  Twenty One Pilots
# 20                                             Sum 41
# 21                                          Cobra Man
# 22                                             Sum 41
# 23                           Shaka Ponk, Cypress Hill
# 24                                              SR-71
# 25                                 Billx, Dr. Peacock
# 26                                             Yvnnis
# 27                                      Nekfeu, Nemir
# 28                                      Billx, Otyken
# 29                                             Yvnnis
# 30                                             Sum 41
# 31                                          Yumi Arai
# 32                                      Alec Benjamin
# 33                        Alan Walker, Sophie Simmons
# 34                    Sadistik, Lotte Kestner, Eyedea
# 35                                  Twenty One Pilots
# 36                                        Linkin Park
# 37                                             Yvnnis
# 38  Alan Walker, Noah Cyrus, Digital Farm Animals,...
# 39                                Ummet Ozcan, Otyken
# 40                                               ROSÉ
# 41                                Alan Walker, Torine
# 42                                               Angy
# 43                                        Alan Walker
# 44                                             Sum 41
# 45                                 Vladimir Cauchemar
# 46                               Alan Walker, Ava Max
# 47                                  Alan Walker, ISÁK
# 48                                        Linkin Park
# 49                   Ashley Johnson, Chris Rondinella
#
#                                                 album  popularity  \
# 0                                              violet          28
# 1                                when the sun came up          28
# 2                                  Now You See Inside          56
# 3                                                GUTS          82
# 4                                     Underclass Hero          60
# 5                                      GUTS (spilled)          70
# 6         The Last of Us Part II: Covers and Rarities          44
# 7   Spider-Man: Into the Spider-Verse (Soundtrack ...          68
# 8                         The Temptations Sing Smokey          78
# 9                      Take Off Your Pants And Jacket          68
# 10                                               DUAL          62
# 11                                     Overcompensate          62
# 12                                           Reckless          70
# 13                              The Emptiness Machine          85
# 14                                           The Drum          59
# 15                                              Chuck          67
# 16                              All Killer, No Filler          74
# 17                             Walkerverse Pt. I & II          53
# 18                                    Heaven :x: Hell          62
# 19                                             Clancy          61
# 20                              All Killer, No Filler          72
# 21                                         Powered Up          38
# 22                           Does This Look Infected?          71
# 23                                          Apelogies          45
# 24                      Here We Go Again (US Edition)          39
# 25                                             Halibo          46
# 26                              L'AFRO OU LES TRESSES          38
# 27                 Les étoiles vagabondes : expansion          62
# 28                          My wing (Rave music edit)          44
# 29                                       GARE DU NORD          38
# 30                                          13 Voices          67
# 31                                        COBALT HOUR          57
# 32                                   Narrated For You          83
# 33                             Walkerverse Pt. I & II          48
# 34                                        Ultraviolet          28
# 35                                             Clancy          67
# 36                                 Heavy Is the Crown          82
# 37                                              NOVAE          40
# 38                                    Different World          63
# 39                                              Altay          47
# 40                                              rosie          80
# 41                                        Hello World          50
# 42                                           Taste Me          34
# 43                                    Different World          59
# 44                                    Heaven :x: Hell          50
# 45                                       Anthropology          46
# 46                                    World Of Walker          71
# 47                                    World Of Walker          52
# 48                                          From Zero          78
# 49        The Last of Us Part II: Covers and Rarities          51
#
#                   id_track
# 0   6wOypcYXXeROfeVQLZ0sVU
# 1   3XlMpNZyNcqH7GxJw0NWH9
# 2   3iwsyTZzOWHZbHffBEyi1N
# 3   1kuGVB7EU95pJObxwvfwKS
# 4   1OTvWduKQV0MQd2gnGM9He
# 5   2U3jOPfO4wZZFaaWS4Dcj6
# 6   3wR4Cnadsl0xnpEAYkr3my
# 7   5zsHmE2gO3RefVsPyw2e3T
# 8   745H5CctFr12Mo7cqa1BMH
# 9   2ydUT1pFhuLDnouelIv4WH
# 10  20Ahyv93KKjMuDHAVy2yjr
# 11  0wEGo9LsSrSUz9HOtraWAO
# 12  5ajjAnNRh8bxFvaVHzpPjh
# 13  2PnlsTsOTLE5jnBnNe2K0A
# 14  1zOOl8f7qkjj0AmvlCfLyQ
# 15  1ibeKVCiXORhvUpMmtsQWq
# 16  1HNE2PX70ztbEl6MLxrpNL
# 17  1hf9Wu2l0XIgAcTZLSAUJe
# 18  5Zq5HHYL8YX2U1S5hY5tRZ
# 19  4hfqe20vqkuRv1RDsA1LbQ
# 20  4KacUpvbA3Mfo05gttTjhN
# 21  35YuZV3Fyffqu9fOO2wXtm
# 22  0jqK7sGTLsHPkQrrcrGuKD
# 23  24ZEVCdOTKgdcM41B598NM
# 24  3JMy4HCSvdwY6FMtvkdKfF
# 25  6M8EMAnTPPnZN58u94iPzg
# 26  2qqXlBPzplDTtKUvbwQ3AI
# 27  4kqsT3yDyJr1KZ2AkM9qfD
# 28  6RBTZTDDdF6LtHRcn4Stlr
# 29  03Wv9gvnH45UU6ssSFai0x
# 30  23Vf9hNoBN8AacpUUHbiRy
# 31  1jw992uwXhqJJ0H42ucTRL
# 32  2qxmye6gAegTMjLKEBoR3d
# 33  2ECNBJ0b112QmhoBHKq8O6
# 34  673iPvgqnCCZdsYhA9qzE6
# 35  1LAlLBTGBUO0MDA8IbSysd
# 36  3fgehc497TFqKH1zBL2YNK
# 37  6rXrpyjMECjAuLlgcW5TXz
# 38  1HvCFAUIWQsWV9zud3UhDl
# 39  2os0CdL7lnGDEpEFMGLcgG
# 40  1lcBt7LoEikqYmhUoa2cez
# 41  1zS7wXUlPhxdOgGZ7RorQ2
# 42  1lPfpbethBQKiALEZ6hjsf
# 43  1tfVpMI8G6EakZU4rEja4w
# 44  4UuGBLZH6ANkF51PqLeXfP
# 45  2v7HFbmmCeraARmBma5pwG
# 46  28VbwtsYnj85UEODGpQRem
# 47  6k1Q8mNcA2jFH0uv5B6g9G
# 48  0J1IJsMbKWb5g2sJArTkGF
# 49  5s78Y4ulsGO9BJh5s3GrL9

# %%
df_tracks_clean = df_tracks_all.filter(items=['popularity','danceability', 'energy', 'key', 'loudness',
       'mode', 'speechiness', 'acousticness', 'instrumentalness', 'liveness',
       'valence', 'tempo'])
df_tracks_clean.head(5)
# Out:
#    popularity  danceability  energy  key  loudness  mode  speechiness  \
# 0          56         0.524   0.967    8    -3.322     1       0.0392
# 1          83         0.652   0.557    1    -5.714     0       0.0318
# 2          28         0.789   0.622    8    -6.878     0       0.1290
#
#    acousticness  instrumentalness  liveness  valence    tempo
# 0      0.000289          0.000007    0.3240    0.731  116.273
# 1      0.740000          0.000000    0.1240    0.483  150.073
# 2      0.107000          0.000000    0.0513    0.254   98.109

# %%
def get_genres_for_artist(artist_id):
    if not access_token:
        print("Erreur : Aucun token d'accès disponible. Authentifiez-vous d'abord")
        return []

    url = f"https://api.spotify.com/v1/artists/{artist_id}"
    headers = {"Authorization": f"Bearer {access_token}"}

    response = requests.get(url, headers=headers)
    if response.status_code == 200:
        artist_data = response.json()
        return artist_data.get("genres", [])
    else:
        print("Erreur :", response.status_code, response.json())
        return []

# %%
def add_genres_to_dataframe(df):
    genres_list = []
    for track_artists in df['artist_ids']:
        artist_ids = track_artists.strip("[]").replace("'", "").split(", ")
        track_genres = set()
        for artist_id in artist_ids:
            track_genres.update(get_genres_for_artist(artist_id))
        genres_list.append(", ".join(track_genres))
    
    df['genres'] = genres_list
    return df

# %%
if 'artist_ids' in df_tracks_all.columns:
    df_tracks_all['artist_ids'] = df_tracks_all['artist_ids'].astype(str)
    df_tracks_with_genres = add_genres_to_dataframe(df_tracks_all)
    df_tracks_clean = df_tracks_with_genres.filter(items=[
        'popularity', 'danceability', 'energy', 'key', 'loudness', 'mode',
        'speechiness', 'acousticness', 'instrumentalness', 'liveness',
        'valence', 'tempo', 'genres'
    ])
    display(df_tracks_clean.head())
else:
    print("La colonne 'artist_ids' est manquante")
# Out:
#    popularity  danceability  energy  key  loudness  mode  speechiness  \
# 0          56         0.524   0.967    8    -3.322     1       0.0392
# 1          83         0.652   0.557    1    -5.714     0       0.0318
# 2          28         0.789   0.622    8    -6.878     0       0.1290
#
#    acousticness  instrumentalness  liveness  valence    tempo  \
# 0      0.000289          0.000007    0.3240    0.731  116.273
# 1      0.740000          0.000000    0.1240    0.483  150.073
# 2      0.107000          0.000000    0.0513    0.254   98.109
#
#                                               genres
# 0
# 1                             pov: indie, alt z, pop
# 2  battle rap, indie psych-pop, seattle hip hop, ...

# %%
from sklearn.preprocessing import StandardScaler, MultiLabelBinarizer
from sklearn.metrics.pairwise import cosine_similarity
import pandas as pd

def recommend_tracks_from_tracks(df, track_id, max_recommendations=50):
    expected_features = ['popularity', 'danceability', 'energy', 'key', 'loudness',
                         'mode', 'speechiness', 'acousticness', 'instrumentalness',
                         'liveness', 'valence', 'tempo', 'genres']
    
    available_features = [col for col in expected_features if col in df.columns]
    
    if not available_features:
        print("Erreur : Aucune des colonnes attendues n'est disponible dans le DataFrame.")
        return pd.DataFrame()

    if track_id not in df['id_track'].values:
        print("Erreur : L'ID de la piste spécifiée n'existe pas dans le DataFrame.")
        return pd.DataFrame()

    if 'genres' in df.columns:
        mlb = MultiLabelBinarizer()
        genre_matrix = mlb.fit_transform(df['genres'].str.split(','))
        genre_df = pd.DataFrame(genre_matrix, columns=mlb.classes_, index=df.index)
        df = pd.concat([df, genre_df], axis=1)
        features_to_scale = [col for col in df.columns if col in expected_features and col != 'genres']
    else:
        genre_df = pd.DataFrame()  # Si les genres n'existent pas, on crée un DataFrame vide
        features_to_scale = [col for col in df.columns if col in expected_features]

    scaler = StandardScaler()
    df_scaled = df.copy()
    df_scaled[features_to_scale] = scaler.fit_transform(df_scaled[features_to_scale])

    track_features = df_scaled[df_scaled['id_track'] == track_id][features_to_scale + list(genre_df.columns)]

    df_scaled['similarity'] = cosine_similarity(
        df_scaled[features_to_scale + list(genre_df.columns)],
        track_features.values.reshape(1, -1)
    ).flatten()

    recommendations = df_scaled[df_scaled['id_track'] != track_id] \
        .sort_values(by='similarity', ascending=False) \
        .head(max_recommendations)

    return recommendations[['id_track', 'similarity', 'name']]

example_track_id = tracks.iloc[0]['id_track'] 
recommended_tracks = recommend_tracks_from_tracks(tracks, example_track_id)
display(recommended_tracks)
# Out:
#                        id_track  similarity  \
# 39200    4FcxMxyUf962mCEQoX8C6y    0.990939
# 869326   2yLFKU0rLvvIOIF0aQmKfS    0.990510
# 549958   3iXKSnl6hmYyn89qUFuiLz    0.990321
# 88612    1Udy7blrWwKMOlpQKlQS82    0.988150
# 983597   3DB9mlwmgdS3WfBFk6Q1UV    0.988013
# 1130919  0MiEhQOPw9IlArjnSLe84w    0.986959
# 142049   6oWHbBzqhimiD9eD3fxLSl    0.986913
# 722712   0k9MB2429OQshdQpLWX8Lf    0.985190
# 889922   1IlcBYJMVZCsd34luxystR    0.985106
# 508735   47e6vGDs0638yHaid4JCMn    0.984910
# 909504   3JF7698CRuzbfRaB14KwBH    0.984842
# 806012   3pJ6HmtYAE5ozttEFRzFZf    0.984588
# 77100    4q3my3KYqtvOx401whpagU    0.984287
# 642237   2mHmNtTholesbhh6phOuBE    0.983240
# 300691   3YHPu6JZq1tBdLbp4uz3c0    0.982990
# 62024    6V72lIG20zIyyrWXbpGjba    0.982870
# 977883   7tUxh9RyblVOEtLZfITblb    0.982263
# 400424   2H6cEhl8U0680JO4OueOW9    0.982080
# 775877   2YvXBUxCGIo0hYBex22R0r    0.982041
# 688091   4BvDfJR8JO3O6EM3HwPVUI    0.981757
# 134264   4kAcdwxEbqslxGYVET18W2    0.981672
# 15771    5CfUrUz4mtLXG5sbtqs6MG    0.981522
# 326364   5FSLDUZGrhZ58TGFl4U9sg    0.981458
# 683970   70kbSyWSROddlrWmuPhhQH    0.981322
# 386985   6rzurm03rVFGKBpI2YrSyz    0.981247
# 800268   7B8FIWP8UhJ5uoUqKTdpBO    0.980129
# 101903   6DICG3kJTgxhOFDr1iZCJA    0.979818
# 988765   4KHRZLQ1ajWVPoFBGGKFfG    0.979311
# 741128   2uvgMKhDtX2De6jACPmr35    0.979158
# 440647   3EF0PoWWAq7tJNMURApm6m    0.979068
# 1152767  7m2cRkG7PDstRNlY1MJUzo    0.978933
# 408382   6MrpxjO5ERWqdknQh7qU36    0.978628
# 684637   0HKTg7kpVWh8thUzfq6hN8    0.978514
# 1041930  0e7lX6cgAwVK5kabBq3Zz7    0.978266
# 1071428  6K3ob7vQUEcOBIsiQcX7hw    0.978198
# 988764   5XbSuIKpFmGyV7M2iHNE37    0.977913
# 1140153  77s5ecj9sn53EX3O0y5Bds    0.977856
# 980350   1cpoBqDPUWlZ8bFiXW4SKc    0.977769
# 600908   5PfzTYF7qbE8GYfqTWm47V    0.977581
# 1010394  7ffmLqNjGZGbWQR1IHrc2q    0.977446
# 722702   2IeggoWCKNuFyd8rF2xlGC    0.977420
# 1080031  3ol7xd4J6aROp2paHWtrrG    0.977244
# 826414   1LiQ5XZjMUF81hHBAOIBnY    0.977227
# 720399   7bBGXUN0ZG90SclN3t1K5j    0.977190
# 775625   6dFJetjPrOCBqnheeqXyhF    0.977122
# 556950   74JblZYzH8AeLIJ9ywR1RW    0.976968
# 712085   5pv1YEjYkJQ0MoFVg2oPjU    0.976717
# 346190   7okaNJsD2ZhWXBl0gL3Crx    0.976714
# 766571   4JUUdGKYwMkZOuMWz2yGr9    0.976540
# 798647   5QtRy3ARRLfmPymVaRFziW    0.976381
#
#                                               name
# 39200                               Daily Revolver
# 869326                     Sleeping Somewhere Else
# 549958                        If Love's the Answer
# 88612                                   Digital On
# 983597                                    Stardust
# 1130919                           One in a Million
# 142049                                Zebra Lounge
# 722712                            Continuity Fails
# 889922                             En Tu Destierro
# 508735                              All My Friends
# 909504                                 Soul Shaker
# 806012                                      Tether
# 77100                                      Aeolian
# 642237                             mouth in a grin
# 300691                              Used to Belong
# 62024                                          Rok
# 977883                               Words Fail Me
# 400424                                Burn it Down
# 775877                                  The Threat
# 688091                                     Oh! No!
# 134264                           Realize Your Mind
# 15771            Sieben Tage, sieben Nächte - Live
# 326364                              Comme un homme
# 683970                            Fiebre De Sabado
# 386985                           People Are People
# 800268                               Midnite Radio
# 101903                               Cinnamon Girl
# 988765                              3 Men 3 Horses
# 741128                                     Verdugo
# 440647                        Under Your Influence
# 1152767                               Ride On Baby
# 408382                                  Lone Rider
# 684637                             Brown Eyed Girl
# 1041930                              Dynamite Mary
# 1071428                             James Connolly
# 988764                       Bad News Travels Fast
# 1140153                                   New Life
# 980350                                  Here We Go
# 600908                               Where I Stand
# 1010394  Cross My Heart - Velvet Acid Christ Remix
# 722702                                Paper Prison
# 1080031                            Betiko Kabroiak
# 826414                    I Don't Think I Love You
# 720399            Siehst Du die Sonne nicht - Live
# 775625                           Freedom From Pain
# 556950                           Shake 'Em On Down
# 712085                                     On & On
# 346190                             Ne jotka tyytyy
# 766571                              Finding My Way
# 798647                           Modern Iconoclast
